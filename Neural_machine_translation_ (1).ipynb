# %%
import re

# %%
#load dataset
with open("/content/fra.txt", "r", encoding="utf-8") as file:
  lines = file.readlines()

# %%
#store sentences pairs
pairs = []
for line in lines:
  words = line.strip().split("\t")[:2]
  if len(words) == 2:
    french = words[0].lower()
    english = words[1].lower()

    #remove special characters and numbers
    french = re.sub(r"[^a-zA-Z]+", " ", french)
    english = re.sub(r"[^a-zA-Z]+", " ", english)

    pairs.append((french, english))

# %%
pairs
# Out:
# [('go ', 'va '),
#  ('go ', 'marche '),
#  ('go ', 'en route '),
#  ('go ', 'bouge '),
#  ('hi ', 'salut '),
#  ('hi ', 'salut '),
#  ('run ', 'cours '),
#  ('run ', 'courez '),
#  ('run ', 'prenez vos jambes vos cous '),
#  ('run ', 'file '),
#  ('run ', 'filez '),
#  ('run ', 'cours '),
#  ('run ', 'fuyez '),
#  ('run ', 'fuyons '),
#  ('run ', 'cours '),
#  ('run ', 'courez '),
#  ('run ', 'prenez vos jambes vos cous '),
#  ('run ', 'file '),
#  ('run ', 'filez '),
#  ('run ', 'cours '),
#  ('run ', 'fuyez '),
#  ('run ', 'fuyons '),
#  ('who ', 'qui '),
#  ('wow ', ' a alors '),
#  ('wow ', 'waouh '),
#  ('wow ', 'wah '),
#  ('duck ', ' terre '),
#  ('duck ', 'baisse toi '),
#  ('duck ', 'baissez vous '),
#  ('fire ', 'au feu '),
#  ('help ', ' l aide '),
#  ('hide ', 'cache toi '),
#  ('hide ', 'cachez vous '),
#  ('jump ', 'saute '),
#  ('jump ', 'saute '),
#  ('stop ', ' a suffit '),
#  ('stop ', 'stop '),
#  ('stop ', 'arr te toi '),
#  ('wait ', 'attends '),
#  ('wait ', 'attendez '),
#  ('wait ', 'attendez '),
#  ('wait ', 'attends '),
#  ('wait ', 'attendez '),
#  ('wait ', 'attends '),
#  ('wait ', 'attendez '),
#  ('begin ', 'commencez '),
#  ('begin ', 'commence '),
#  ('go on ', 'poursuis '),
#  ('go on ', 'continuez '),
#  ('go on ', 'poursuivez '),
#  ('hello ', 'bonjour '),
#  ('hello ', 'salut '),
#  ('hello ', 'bonjour '),
#  ('hello ', 'salut '),
#  ('hello ', 'bonjour '),
#  ('hello ', 'salut '),
#  ('i see ', 'je comprends '),
#  ('i see ', 'aha '),
#  ('i try ', 'j essaye '),
#  ('i won ', 'j ai gagn '),
#  ('i won ', 'je l ai emport '),
#  ('i won ', 'j ai gagn '),
#  ('oh no ', 'oh non '),
#  ('relax ', 'calme toi '),
#  ('relax ', 'd tends toi '),
#  ('relax ', 'd tendez vous '),
#  ('relax ', 'relaxe max '),
#  ('relax ', 'cool raoul '),
#  ('relax ', 'du calme '),
#  ('relax ', 'relaxe '),
#  ('relax ', 'calmez vous '),
#  ('relax ', 'd tends toi '),
#  ('relax ', 'd tends toi '),
#  ('relax ', 'du calme '),
#  ('relax ', 'tranquille '),
#  ('smile ', 'souriez '),
#  ('smile ', 'souris pour la cam ra '),
#  ('smile ', 'souriez '),
#  ('sorry ', 'pardon '),
#  ('attack ', 'attaque '),
#  ('attack ', 'attaquez '),
#  ('attack ', ' l attaque '),
#  ('attack ', ' l attaque '),
#  ('buy it ', 'achetez la '),
#  ('buy it ', 'ach te le '),
#  ('buy it ', 'achetez le '),
#  ('buy it ', 'ach te la '),
#  ('cheers ', 'sant '),
#  ('cheers ', ' votre sant '),
#  ('cheers ', 'merci '),
#  ('cheers ', 'tchin tchin '),
#  ('eat it ', 'mangez le '),
#  ('eat it ', 'mange le '),
#  ('exhale ', 'expire '),
#  ('get up ', 'l ve toi '),
#  ('get up ', 'l ve toi '),
#  ('get up ', 'debout '),
#  ('go now ', 'va maintenant '),
#  ('go now ', 'allez y maintenant '),
#  ('go now ', 'vas y maintenant '),
#  ('got it ', 'j ai pig '),
#  ('got it ', 'compris '),
#  ('got it ', 'aha '),
#  ('got it ', 'pig '),
#  ('got it ', 'compris '),
#  ('got it ', 't as capt '),
#  ('hop in ', 'monte '),
#  ('hop in ', 'montez '),
#  ('hug me ', 'serre moi dans tes bras '),
#  ('hug me ', 'serrez moi dans vos bras '),
#  ('i fell ', 'je suis tomb e '),
#  ('i fell ', 'je suis tomb '),
#  ('i fled ', 'j ai fui '),
#  ('i hunt ', 'je chasse '),
#  ('i knit ', 'je tricote '),
#  ('i know ', 'je sais '),
#  ('i left ', 'je suis parti '),
#  ('i left ', 'je suis partie '),
#  ('i lied ', 'j ai menti '),
#  ('i lost ', 'j ai perdu '),
#  ('i paid ', 'je payais '),
#  ('i paid ', 'je payai '),
#  ('i paid ', 'j ai pay '),
#  ('i pass ', 'je passe '),
#  ('i quit ', 'j arr te '),
#  ('i quit ', 'j ai arr t '),
#  ('i swim ', 'je nage '),
#  ('i m ', 'j ai ans '),
#  ('i m ok ', 'je vais bien '),
#  ('i m ok ', ' a va '),
#  ('inhale ', 'inspire '),
#  ('listen ', ' coutez '),
#  ('no way ', 'c est pas possible '),
#  ('no way ', 'impossible '),
#  ('no way ', 'hors de question '),
#  ('no way ', 'en aucun cas '),
#  ('no way ', 'sans fa ons '),
#  ('no way ', 'mon il '),
#  ('no way ', 'c est hors de question '),
#  ('no way ', 'il n en est pas question '),
#  ('no way ', 'c est exclu '),
#  ('no way ', 'en aucune mani re '),
#  ('no way ', 'hors de question '),
#  ('no way ', 'sans blague '),
#  ('really ', 'vraiment '),
#  ('really ', 'vrai '),
#  ('really ', 'ah bon '),
#  ('really ', 'ah vraiment '),
#  ('really ', 'vraiment '),
#  ('thanks ', 'merci '),
#  ('thanks ', 'je te remercie '),
#  ('thanks ', 'merci '),
#  ('thanks ', 'merci '),
#  ('try it ', 'essaie '),
#  ('try it ', 'essayez '),
#  ('try it ', 'essaye '),
#  ('we try ', 'on essaye '),
#  ('we won ', 'nous avons gagn '),
#  ('we won ', 'nous gagn mes '),
#  ('we won ', 'nous l avons emport '),
#  ('we won ', 'nous l emport mes '),
#  ('we won ', 'on a gagn '),
#  ('ask tom ', 'demande tom '),
#  ('ask him ', 'demande lui '),
#  ('awesome ', 'fantastique '),
#  ('awesome ', 'sensass '),
#  ('awesome ', 'trop cool '),
#  ('awesome ', 'g nial '),
#  ('be calm ', 'sois calme '),
#  ('be calm ', 'soyez calme '),
#  ('be calm ', 'soyez calmes '),
#  ('be cool ', 'sois d tendu '),
#  ('be fair ', 'sois juste '),
#  ('be fair ', 'soyez juste '),
#  ('be fair ', 'soyez justes '),
#  ('be fair ', 'sois quitable '),
#  ('be fair ', 'soyez quitable '),
#  ('be fair ', 'soyez quitables '),
#  ('be fair ', 'sois honn te '),
#  ('be fair ', 'sois sinc re '),
#  ('be fair ', 'soyez honn tes '),
#  ('be kind ', 'sois gentil '),
#  ('be nice ', 'sois gentil '),
#  ('be nice ', 'sois gentille '),
#  ('be nice ', 'soyez gentil '),
#  ('be nice ', 'soyez gentille '),
#  ('be nice ', 'soyez gentils '),
#  ('be nice ', 'soyez gentilles '),
#  ('beat it ', 'cassez vous '),
#  ('beat it ', 'va te faire foutre '),
#  ('beat it ', 'd gage '),
#  ('beat it ', 'casse toi '),
#  ('beat it ', 'pars '),
#  ('beat it ', 'foutez le camp '),
#  ('beat it ', 'fous le camp '),
#  ('beat it ', 'pars d ici '),
#  ('beat it ', 'va t en '),
#  ('beat it ', 'disparais '),
#  ('beat it ', 'fiche le camp '),
#  ('beat it ', 'tire toi de l '),
#  ('beat it ', 'casse toi de l '),
#  ('beat it ', 'oust '),
#  ('beat it ', 'd gage '),
#  ('beat it ', 'fiche le camp d ici '),
#  ('beat it ', 'd guerpissez '),
#  ('beat it ', 'bouge '),
#  ('beat it ', 'd campe '),
#  ('burn it ', 'br lez le '),
#  ('burn it ', 'br lez la '),
#  ('burn it ', 'br le la '),
#  ('burn it ', 'br le le '),
#  ('bury it ', 'enterrez le '),
#  ('bury it ', 'enterre le '),
#  ('bury it ', 'enterrez la '),
#  ('bury it ', 'enterre la '),
#  ('call me ', 'appelle moi '),
#  ('call me ', 'appelez moi '),
#  ('call us ', 'appelle nous '),
#  ('call us ', 'appelez nous '),
#  ('come in ', 'entrez '),
#  ('come in ', 'entre '),
#  ('come in ', 'entre '),
#  ('come in ', 'entrez '),
#  ('come on ', 'allez '),
#  ('come on ', 'en avant '),
#  ('come on ', 'allons '),
#  ('come on ', 'c est pas vrai dis '),
#  ('come on ', 'viens '),
#  ('come on ', 'venez '),
#  ('come on ', 'secouez vous '),
#  ('come on ', 'secoue toi '),
#  ('come on ', 'allez on y va '),
#  ('come on ', 'allez '),
#  ('come on ', 'viens '),
#  ('come on ', 'venez '),
#  ('drop it ', 'laisse tomber '),
#  ('drop it ', 'laissez tomber '),
#  ('drop it ', 'laisse le tomber '),
#  ('drop it ', 'laissez le tomber '),
#  ('fold it ', 'pliez le '),
#  ('fold it ', 'plie le '),
#  ('fold it ', 'pliez la '),
#  ('fold it ', 'plie la '),
#  ('get tom ', 'va chercher tom '),
#  ('get out ', 'sors '),
#  ('get out ', 'sortez '),
#  ('get out ', 'd gage '),
#  ('get out ', 'disparais '),
#  ('get out ', 'casse toi '),
#  ('get out ', 'd gagez '),
#  ('get out ', 'sors '),
#  ('get out ', 'sortez '),
#  ('get out ', 'd gage '),
#  ('get out ', 'disparais '),
#  ('get out ', 'du balai '),
#  ('get out ', 'fiche le camp '),
#  ('get out ', 'oust '),
#  ('get out ', 'vers l ext rieur '),
#  ('get out ', 'fichez le camp '),
#  ('get out ', 'sortez '),
#  ('get out ', 'd campez '),
#  ('get out ', 'd campe '),
#  ('get out ', 'sors '),
#  ('get out ', 'sortez '),
#  ('get out ', 'd gage '),
#  ('get out ', 'disparais '),
#  ('get out ', 'casse toi '),
#  ('get out ', 'd gagez '),
#  ('get out ', 'sors '),
#  ('get out ', 'sortez '),
#  ('get out ', 'disparais '),
#  ('get out ', 'fiche le camp '),
#  ('get out ', 'oust '),
#  ('get out ', 'sortez '),
#  ('get out ', 'bouge '),
#  ('get out ', 'd campez '),
#  ('get out ', 'd campe '),
#  ('go away ', 'd gage '),
#  ('go away ', 'pars '),
#  ('go away ', 'allez vous en '),
#  ('go away ', 'd guerpissez '),
#  ('go away ', 'cassez vous '),
#  ('go away ', 'bouge '),
#  ('go away ', 'd campez '),
#  ('go away ', 'd campe '),
#  ('go away ', 'va te faire foutre '),
#  ('go away ', 'pars '),
#  ('go away ', 'd gage '),
#  ('go away ', 'fous le camp '),
#  ('go away ', 'pars d ici '),
#  ('go away ', 'va t en '),
#  ('go away ', 'disparais '),
#  ('go away ', 'd guerpissez '),
#  ('go away ', 'cassez vous '),
#  ('go away ', 'bouge '),
#  ('go away ', 'd campez '),
#  ('go away ', 'd campe '),
#  ('go away ', 'allez vous en '),
#  ('go back ', 'recule '),
#  ('go home ', 'rentrez la maison '),
#  ('go home ', 'rentre la maison '),
#  ('go home ', 'rentre chez toi '),
#  ('go home ', 'rentrez chez vous '),
#  ('go slow ', 'va doucement '),
#  ('go slow ', 'allez doucement '),
#  ('goodbye ', 'adieu '),
#  ('goodbye ', ' la revoyure '),
#  ('goodbye ', 'ciao '),
#  ('goodbye ', 'au revoir '),
#  ('goodbye ', 'ciao '),
#  ('hang on ', 'attends un peu '),
#  ('hang on ', 'attendez un peu '),
#  ('hang on ', 'attendez '),
#  ('hang on ', 'tiens bon '),
#  ('hang on ', 'tenez bon '),
#  ('hang on ', 'attendez '),
#  ('he left ', 'il est parti '),
#  ('he runs ', 'il court '),
#  ('help me ', 'aide moi '),
#  ('help me ', ' l aide '),
#  ('help me ', 'aide moi '),
#  ('help me ', 'aidez moi '),
#  ('help me ', 'aide moi '),
#  ('help us ', 'aidez nous '),
#  ('help us ', 'aide nous '),
#  ('hire me ', 'engagez moi '),
#  ('hire me ', 'engage moi '),
#  ('hire me ', 'embauchez moi '),
#  ('hire me ', 'embauche moi '),
#  ('hold it ', 'ne bouge plus '),
#  ('hold it ', 'ne bougez plus '),
#  ('hold it ', 'restez o vous tes '),
#  ('hold it ', 'attendez '),
#  ('hold on ', 'ne quittez pas '),
#  ('hold on ', 'attends '),
#  ('hold on ', 'ne quitte pas '),
#  ('hold on ', 'accroche toi '),
#  ('hold on ', 'tiens bon '),
#  ('hold up ', 'tiens bon '),
#  ('hold up ', 'tenez bon '),
#  ('how sad ', 'comme c est triste '),
#  ('hug tom ', 'fais un c lin tom '),
#  ('i agree ', 'je suis du m me avis '),
#  ('i cried ', 'j ai pleur '),
#  ('i dozed ', 'je me suis assoupi '),
#  ('i dozed ', 'je me suis assoupie '),
#  ('i drive ', 'je conduis '),
#  ('i drove ', 'je conduisis '),
#  ('i fired ', 'j ai tir '),
#  ('i froze ', 'je me suis fig '),
#  ('i froze ', 'je me suis fig e '),
#  ('i smoke ', 'je fume '),
#  ('i snore ', 'je ronfle '),
#  ('i stink ', 'je pue '),
#  ('i stood ', 'je me suis tenu debout '),
#  ('i stood ', 'je me suis tenue debout '),
#  ('i swore ', 'j ai promis '),
#  ('i swore ', 'j ai jur '),
#  ('i tried ', 'j essayai '),
#  ('i tried ', 'j ai essay '),
#  ('i tried ', 'j ai tent '),
#  ('i waved ', 'j ai fait signe '),
#  ('i ll go ', 'j irai '),
#  ('i m tom ', 'je suis tom '),
#  ('i m fat ', 'je suis gras '),
#  ('i m fat ', 'je suis gros '),
#  ('i m fit ', 'je suis en forme '),
#  ('i m hit ', 'je suis touch '),
#  ('i m hit ', 'je suis touch e '),
#  ('i m ill ', 'je suis malade '),
#  ('i m mad ', 'je suis fou '),
#  ('i m mad ', 'je suis folle '),
#  ('i m mad ', 'je suis en col re '),
#  ('i m sad ', 'je suis triste '),
#  ('i m sad ', 'j ai un coup de cafard '),
#  ('i m sad ', 'je suis malheureux '),
#  ('i m shy ', 'je suis timide '),
#  ('i m wet ', 'je suis mouill '),
#  ('i m wet ', 'je suis mouill e '),
#  ('it s me ', 'c est bibi '),
#  ('join me ', 'rejoignez moi '),
#  ('join us ', 'joignez vous '),
#  ('join us ', 'joignez vous nous '),
#  ('keep it ', 'garde le '),
#  ('keep it ', 'gardez le '),
#  ('kick it ', 'donne lui un coup de pied '),
#  ('kick it ', 'donnez lui un coup de pied '),
#  ('kill it ', 'tuez le '),
#  ('kill it ', 'tue le '),
#  ('kill it ', 'tue la '),
#  ('kill it ', 'tuez la '),
#  ('kiss me ', 'embrasse moi '),
#  ('kiss me ', 'embrassez moi '),
#  ('lie low ', ' terre '),
#  ('lie low ', 'au sol '),
#  ('lock it ', 'verrouillez le '),
#  ('lock it ', 'verrouille le '),
#  ('lock it ', 'verrouillez la '),
#  ('lock it ', 'verrouille la '),
#  ('look up ', 'levez les yeux '),
#  ('look up ', 'l ve les yeux '),
#  ('me too ', 'moi aussi '),
#  ('me too ', ' moi aussi '),
#  ('move on ', 'passez autre chose '),
#  ('move on ', 'passe autre chose '),
#  ('open it ', 'ouvrez le '),
#  ('open it ', 'ouvre le '),
#  ('open it ', 'ouvre la '),
#  ('open it ', 'ouvrez la '),
#  ('open up ', 'ouvre moi '),
#  ('open up ', 'ouvre '),
#  ('pair up ', 'faites quipe '),
#  ('perfect ', 'parfait '),
#  ('perfect ', 'nickel '),
#  ('perfect ', 'parfait '),
#  ('pull it ', 'tirez dessus '),
#  ('pull it ', 'tire dessus '),
#  ('push it ', 'appuie dessus '),
#  ('push it ', 'poussez le '),
#  ('push it ', 'pousse le '),
#  ('push it ', 'poussez la '),
#  ('push it ', 'pousse la '),
#  ('see you ', ' plus tard '),
#  ('see you ', ' bient t '),
#  ('see you ', ' la prochaine '),
#  ('see you ', 'ciao '),
#  ('see you ', ' plus '),
#  ('see you ', 'ciao '),
#  ('show me ', 'montre moi '),
#  ('show me ', 'montrez moi '),
#  ('shut up ', 'taisez vous '),
#  ('shut up ', 'ferme la '),
#  ('shut up ', 'tais toi '),
#  ('shut up ', 'ferme la '),
#  ('shut up ', 'la ferme '),
#  ('shut up ', 'bouclez la '),
#  ('shut up ', 'fermez la '),
#  ('shut up ', 'ferme la '),
#  ('sign up ', 'inscrivez vous '),
#  ('sign up ', 'inscris toi '),
#  ('skip it ', 'laisse tomber '),
#  ('skip it ', 'pas grave '),
#  ('so long ', ' plus tard '),
#  ('take it ', 'prends le '),
#  ('take it ', 'prenez le '),
#  ('take it ', 'prends le '),
#  ('take it ', 'prenez le '),
#  ('take it ', 'prenez le '),
#  ('take it ', 'prends le '),
#  ('tell me ', 'dis moi '),
#  ('tell me ', 'dites moi '),
#  ('tom won ', 'tom a gagn '),
#  ('wake up ', 'r veille toi '),
#  ('wake up ', 'r veille toi '),
#  ('wake up ', 'r veillez vous '),
#  ('wake up ', 'r veille toi '),
#  ('wake up ', 'r veillez vous '),
#  ('wash up ', 'lave toi '),
#  ('wash up ', 'lavez vous '),
#  ('we care ', 'nous nous en soucions '),
#  ('we know ', 'nous savons '),
#  ('we know ', 'on sait '),
#  ('we lost ', 'nous perd mes '),
#  ('we lost ', 'nous avons perdu '),
#  ('we lost ', 'nous f mes battus '),
#  ('we lost ', 'nous f mes battues '),
#  ('we lost ', 'nous f mes d faits '),
#  ('we lost ', 'nous f mes d faites '),
#  ('we lost ', 'nous avons t d faits '),
#  ('we lost ', 'nous avons t d faites '),
#  ('we lost ', 'nous avons t battus '),
#  ('we lost ', 'nous avons t battues '),
#  ('welcome ', 'bienvenue '),
#  ('welcome ', 'soyez le bienvenu '),
#  ('who ran ', 'qui courait '),
#  ('who won ', 'qui a gagn '),
#  ('who won ', 'qui l a emport '),
#  ('you run ', 'tu cours '),
#  ('you win ', 'vous avez gagn '),
#  ('aim high ', 'visez haut '),
#  ('aim high ', 'vise haut '),
#  ('am i fat ', 'suis je gros '),
#  ('am i fat ', 'suis je grosse '),
#  ('ask them ', 'demande leur '),
#  ('ask them ', 'demandez leur '),
#  ('back off ', 'recule '),
#  ('back off ', 'reculez '),
#  ('back off ', 'cassez vous '),
#  ('back off ', 'recule '),
#  ('back off ', 'reculez '),
#  ('back off ', 'retire toi '),
#  ('back off ', 'retirez vous '),
#  ('back off ', 'cassez vous '),
#  ('be a man ', 'sois un homme '),
#  ('be a man ', 'soyez un homme '),
#  ('be brave ', 'soyez courageux '),
#  ('be brief ', 'soyez bref '),
#  ('be brief ', 'sois bref '),
#  ('be brief ', 'sois br ve '),
#  ('be brief ', 'soyez br ve '),
#  ('be brief ', 'soyez brefs '),
#  ('be brief ', 'soyez br ves '),
#  ('be still ', 'sois calme '),
#  ('be still ', 'soyez calme '),
#  ('be still ', 'soyez calmes '),
#  ('buzz off ', 'casse toi '),
#  ('call tom ', 'appelle tom '),
#  ('call tom ', 'appelez tom '),
#  ('can i go ', 'je peux y aller '),
#  ('cheer up ', 'courage '),
#  ('cheer up ', 'courage '),
#  ('cool off ', 'd tends toi '),
#  ('cover me ', 'couvre moi '),
#  ('cuff him ', 'menottez le '),
#  ('drive on ', 'avance '),
#  ('drive on ', 'avancez '),
#  ('drive on ', 'continue rouler '),
#  ('drive on ', 'continuez rouler '),
#  ('find tom ', 'trouve tom '),
#  ('find tom ', 'trouvez tom '),
#  ('fix this ', 'r parez ceci '),
#  ('fix this ', 'r pare a '),
#  ('get away ', 'd gage '),
#  ('get away ', 'casse toi '),
#  ('get away ', 'pars '),
#  ('get away ', 'd gage '),
#  ('get away ', 'fous le camp '),
#  ('get away ', 'pars d ici '),
#  ('get away ', 'va t en '),
#  ('get away ', ' carte toi '),
#  ('get away ', 'disparais '),
#  ('get away ', 'allez vous en '),
#  ('get away ', 'fiche le camp '),
#  ('get away ', 'tire toi de l '),
#  ('get away ', 'd gage '),
#  ('get away ', 'va t en '),
#  ('get away ', 'criss ton camp d icit '),
#  ('get away ', 'fichez le camp '),
#  ('get away ', 'd guerpissez '),
#  ('get away ', 'cassez vous '),
#  ('get away ', 'barrez vous '),
#  ('get away ', 'barre toi '),
#  ('get away ', 'va t en '),
#  ('get away ', 'bouge '),
#  ('get away ', 'd campez '),
#  ('get away ', 'd campe '),
#  ('get away ', 'tu dis n importe quoi '),
#  ('get away ', 'pars '),
#  ('get away ', 'partez '),
#  ('get down ', 'l che toi '),
#  ('get down ', ' terre '),
#  ('get down ', 'au sol '),
#  ('get down ', 'descends '),
#  ('get down ', 'descends '),
#  ('get down ', 'descendez '),
#  ('get down ', 'l che toi '),
#  ('get down ', 'l chez vous '),
#  ('get down ', ' terre '),
#  ('get down ', 'au sol '),
#  ('get down ', 'descends '),
#  ('get lost ', 'va voir ailleurs si j y suis '),
#  ('get lost ', 'd gage '),
#  ('get lost ', 'va au diable '),
#  ('get lost ', 'd guerpissez '),
#  ('get lost ', 'cassez vous '),
#  ('get lost ', 'bouge '),
#  ('get lost ', 'd campez '),
#  ('get lost ', 'd campe '),
#  ('get lost ', 'va te faire foutre '),
#  ('get lost ', 'va te faire voir '),
#  ('get lost ', 'fiche le camp '),
#  ('get lost ', 'fichez le camp '),
#  ('get lost ', 'd guerpissez '),
#  ('get lost ', 'cassez vous '),
#  ('get lost ', 'bouge '),
#  ('get lost ', 'd campez '),
#  ('get lost ', 'd campe '),
#  ('get real ', 'sois r aliste '),
#  ('get real ', 'tu d lires '),
#  ('go ahead ', 'allez '),
#  ('go ahead ', 'vas y '),
#  ('go ahead ', 'en avant '),
#  ('go ahead ', 'va '),
#  ('go ahead ', 'poursuis '),
#  ('go ahead ', 'poursuivez '),
#  ('go ahead ', 'passe devant '),
#  ('go ahead ', 'vas y '),
#  ('go ahead ', 'allez y '),
#  ('go ahead ', 'continuez '),
#  ('go ahead ', 'continue '),
#  ('go ahead ', 'allez '),
#  ('go ahead ', 'avance '),
#  ('go ahead ', 'en avant '),
#  ('go ahead ', 'allez '),
#  ('go ahead ', 'vas y '),
#  ('go ahead ', 'va '),
#  ('go ahead ', 'poursuis '),
#  ('go ahead ', 'poursuivez '),
#  ('go ahead ', 'passe devant '),
#  ('go ahead ', 'vas y '),
#  ('go ahead ', 'allez y '),
#  ('go ahead ', 'continuez '),
#  ('go ahead ', 'continue '),
#  ('go ahead ', 'allez '),
#  ('go ahead ', 'avance '),
#  ('go ahead ', 'en route '),
#  ('good job ', 'bien jou '),
#  ('good job ', 'bon boulot '),
#  ('good job ', 'beau travail '),
#  ('good job ', 'bravo '),
#  ('grab tom ', 'attrape tom '),
#  ('grab tom ', 'attrapez tom '),
#  ('grab him ', 'attrape le '),
#  ('grab him ', 'attrapez le '),
#  ('grab him ', 'mettez lui la main dessus '),
#  ('have fun ', 'amuse toi bien '),
#  ('have fun ', 'amusez vous bien '),
#  ('have fun ', 'amuse toi bien '),
#  ('have fun ', 'amusez vous bien '),
#  ('he spoke ', 'il a parl '),
#  ('he spoke ', 'il a pris la parole '),
#  ('he spoke ', 'il s est exprim '),
#  ('he tries ', 'il essaye '),
#  ('he s wet ', 'il est mouill '),
#  ('help tom ', 'aide tom '),
#  ('help tom ', 'aidez tom '),
#  ('help tom ', 'aidez tom '),
#  ('hi guys ', 'salut les mecs '),
#  ('hit back ', 'riposte '),
#  ('hit back ', 'ripostez '),
#  ('how cute ', 'comme c est mignon '),
#  ('how cute ', 'trop mignon '),
#  ('how cute ', 'trop mignonne '),
#  ('how deep ', 'quelle profondeur '),
#  ('how nice ', 'comme elle est belle '),
#  ('how nice ', 'comme c est chouette '),
#  ('how nice ', 'comme c est gentil '),
#  ('how nice ', 'c est du joli '),
#  ('how nice ', 'comme c est agr able '),
#  ('how rude ', 'quelle grossi ret '),
#  ('how wise ', 'quelle sagesse '),
#  ('hurry up ', 'd p che toi '),
#  ('hurry up ', 'grouille '),
#  ('hurry up ', 'pressez vous '),
#  ('hurry up ', 'fi a '),
#  ('hurry up ', 'magne toi '),
#  ('hurry up ', 'magnez vous '),
#  ('i am tom ', 'je suis tom '),
#  ('i cursed ', 'j ai jur '),
#  ('i did ok ', 'je m en suis bien sorti '),
#  ('i did ok ', 'je m en suis bien sortie '),
#  ('i did it ', 'je l ai fait '),
#  ('i did it ', 'c est moi qui l ai fait '),
#  ('i failed ', 'j ai chou '),
#  ('i forgot ', 'j ai oubli '),
#  ('i get it ', 'j ai compris '),
#  ('i goofed ', 'j ai fait une gaffe '),
#  ('i goofed ', 'j ai fait une bourde '),
#  ('i goofed ', 'j ai fait une boulette '),
#  ('i got it ', 'j ai compris '),
#  ('i got it ', 'j ai capt '),
#  ('i helped ', 'j ai aid '),
#  ('i jumped ', 'j ai saut '),
#  ('i looked ', 'j ai regard '),
#  ('i moaned ', 'j ai r l '),
#  ('i nodded ', 'j ai fait signe de la t te '),
#  ('i obeyed ', 'j ai ob i '),
#  ('i phoned ', 'je t l phonai '),
#  ('i phoned ', 'j ai t l phon '),
#  ('i refuse ', 'je refuse '),
#  ('i refuse ', 'je le refuse '),
#  ('i rested ', 'je me suis repos '),
#  ('i rested ', 'je me suis repos e '),
#  ('i saw it ', 'je l ai vu '),
#  ('i saw it ', 'je l ai vu '),
#  ('i sighed ', 'j ai soupir '),
#  ('i smiled ', 'j ai souri '),
#  ('i stayed ', 'je suis rest '),
#  ('i stayed ', 'je suis rest e '),
#  ('i talked ', 'j ai parl '),
#  ('i use it ', 'je l utilise '),
#  ('i use it ', 'j en fais usage '),
#  ('i use it ', 'je m en sers '),
#  ('i ll pay ', 'je paierai '),
#  ('i ll pay ', 'je paie '),
#  ('i ll try ', 'je vais essayer '),
#  ('i ll try ', 'j essaierai '),
#  ('i m back ', 'je suis revenu '),
#  ('i m back ', 'me revoil '),
#  ('i m bald ', 'je suis chauve '),
#  ('i m busy ', 'je suis occup '),
#  ('i m busy ', 'je suis occup e '),
#  ('i m calm ', 'je suis calme '),
#  ('i m cold ', 'j ai froid '),
#  ('i m cool ', 'je suis d tendu '),
#  ('i m cool ', 'je suis d tendue '),
#  ('i m deaf ', 'je suis sourd '),
#  ('i m deaf ', 'je suis sourde '),
#  ('i m done ', 'j en ai fini '),
#  ('i m fair ', 'je suis juste '),
#  ('i m fair ', 'j ai la peau claire '),
#  ('i m fair ', 'j ai le teint clair '),
#  ('i m fast ', 'je suis rapide '),
#  ('i m fine ', 'tout va bien '),
#  ('i m fine ', 'je vais bien '),
#  ('i m fine ', ' a va '),
#  ('i m free ', 'je suis libre '),
#  ('i m free ', 'je suis libre '),
#  ('i m free ', 'je suis disponible '),
#  ('i m full ', 'je suis repu '),
#  ('i m full ', 'je suis rassasi '),
#  ('i m game ', 'j en suis '),
#  ('i m game ', 'je suis de la partie '),
#  ('i m glad ', 'je suis content '),
#  ('i m good ', 'je vais bien '),
#  ('i m good ', 'je suis bon '),
#  ('i m home ', 'je suis chez moi '),
#  ('i m late ', 'je suis en retard '),
#  ('i m lazy ', 'je suis paresseux '),
#  ('i m lazy ', 'je suis fain ant '),
#  ('i m lazy ', 'je suis paresseuse '),
#  ('i m lazy ', 'je suis fain ante '),
#  ('i m lost ', 'je suis paum '),
#  ('i m lost ', 'je suis perdue '),
#  ('i m okay ', 'je vais bien '),
#  ('i m okay ', 'je me porte bien '),
#  ('i m rich ', 'je suis riche '),
#  ('i m safe ', 'je suis en s curit '),
#  ('i m sick ', 'je suis malade '),
#  ('i m sure ', 'j en suis certain '),
#  ('i m sure ', 'je suis certain '),
#  ('i m sure ', 'j en suis s r '),
#  ('i m sure ', 'j en suis s re '),
#  ('i m tall ', 'je suis grande '),
#  ('i m thin ', 'je suis mince '),
#  ('i m tidy ', 'je suis ordonn '),
#  ('i m tidy ', 'je suis ordonn e '),
#  ('i m ugly ', 'je suis laid '),
#  ('i m ugly ', 'je suis laide '),
#  ('i m ugly ', 'je suis moche '),
#  ('i m weak ', 'je suis faible '),
#  ('i m well ', 'je vais bien '),
#  ('i m well ', 'je me porte bien '),
#  ('i ve won ', 'j ai gagn '),
#  ('i ve won ', 'je l ai emport '),
#  ('it helps ', ' a aide '),
#  ('it hurts ', ' a fait mal '),
#  ('it works ', 'elle marche '),
#  ('it works ', ' a fonctionne '),
#  ('it s tom ', 'c est tom '),
#  ('it s fun ', 'c est marrant '),
#  ('it s fun ', 'c est rigolo '),
#  ('it s his ', 'c est le sien '),
#  ('it s his ', 'c est la sienne '),
#  ('it s hot ', 'c est chaud '),
#  ('it s new ', 'c est nouveau '),
#  ('it s new ', 'c est neuf '),
#  ('it s odd ', 'c est bizarre '),
#  ('it s red ', 'il est rouge '),
#  ('it s sad ', 'c est triste '),
#  ('keep out ', 'd fense d entrer '),
#  ('keep out ', 'n entrez pas '),
#  ('kill tom ', 'tuez tom '),
#  ('kill tom ', 'tue tom '),
#  ('kiss tom ', 'embrasse tom '),
#  ('leave it ', 'laisse tomber '),
#  ('leave it ', 'laissez tomber '),
#  ('leave it ', 'laisse '),
#  ('leave it ', 'laissez a '),
#  ('leave it ', 'laisse a '),
#  ('leave me ', 'laissez moi '),
#  ('leave us ', 'laisse nous '),
#  ('leave us ', 'laissez nous '),
#  ('let s go ', 'allons y '),
#  ('let s go ', 'allons '),
#  ('let s go ', 'en route '),
#  ('let s go ', 'allons y '),
#  ('let s go ', 'en route '),
#  ('look out ', 'attention '),
#  ('look out ', 'faites attention '),
#  ('look out ', 'fais attention '),
#  ('look out ', 'soyez prudente '),
#  ('look out ', 'fais gaffe '),
#  ('look out ', 'faites gaffe '),
#  ('look out ', 'fais attention '),
#  ('look out ', 'regarde donc '),
#  ('look out ', 'faites attention '),
#  ('look out ', 'fais attention '),
#  ('marry me ', ' pouse moi '),
#  ('marry me ', ' pousez moi '),
#  ('may i go ', 'puis je partir '),
#  ('may i go ', 'puis je y aller '),
#  ('may i go ', 'puis je m y rendre '),
#  ('nice try ', 'belle tentative '),
#  ('now stop ', 'arr tez vous maintenant '),
#  ('now stop ', 'arr te toi maintenant '),
#  ('prove it ', 'prouvez le '),
#  ('prove it ', 'prouve le '),
#  ('run away ', 'fuyez '),
#  ('run away ', 'fuis '),
#  ('run away ', 'enfuyez vous '),
#  ('run away ', 'enfuis toi '),
#  ('save tom ', 'sauve tom '),
#  ('save tom ', 'sauvez tom '),
#  ('say what ', 'de quoi '),
#  ('she came ', 'elle est venue '),
#  ('she died ', 'elle est morte '),
#  ('she left ', 'elle est partie '),
#  ('she runs ', 'elle court '),
#  ('sit down ', 'assieds toi '),
#  ('sit down ', 'asseyez vous '),
#  ('sit down ', 'asseyez vous '),
#  ('sit down ', 'assieds toi '),
#  ('sit down ', 'asseyez vous '),
#  ('sit here ', 'assieds toi ici '),
#  ('sit here ', 'asseyez vous ici '),
#  ('speak up ', 'parle plus fort '),
#  ('speak up ', 'parlez plus fort '),
#  ('speak up ', 'parle plus fort '),
#  ('speed up ', 'acc l re '),
#  ('speed up ', 'acc l rez '),
#  ('stand up ', 'l ve toi '),
#  ('stop tom ', 'arr te tom '),
#  ('stop tom ', 'stoppez tom '),
#  ('take tom ', 'prends tom '),
#  ('taste it ', 'go te le '),
#  ('taste it ', 'go te la '),
#  ('taste it ', 'go tez le '),
#  ('taste it ', 'go tez la '),
#  ('tell tom ', 'dis le tom '),
#  ('tell tom ', 'informez en tom '),
#  ('terrific ', 'fantastique '),
#  ('terrific ', 'g nial '),
#  ('terrific ', 'super '),
#  ('terrific ', 'au poil '),
#  ('terrific ', 'impeccable '),
#  ('terrific ', 'nickel '),
#  ('terrific ', 'excellent '),
#  ('terrific ', 'magnifique '),
#  ('terrific ', 'nickel chrome '),
#  ('terrific ', 'bien '),
#  ('terrific ', 'formidable '),
#  ('terrific ', 'c est g nial '),
#  ('terrific ', ' la bonne heure '),
#  ('terrific ', 'c est super '),
#  ('terrific ', 'super '),
#  ('terrific ', 'g nial '),
#  ('terrific ', 'sensass '),
#  ('they won ', 'ils gagn rent '),
#  ('they won ', 'elles gagn rent '),
#  ('they won ', 'ils ont gagn '),
#  ('they won ', 'elles ont gagn '),
#  ('tom came ', 'tom est venu '),
#  ('tom died ', 'tom est mort '),
#  ('tom knew ', 'tom savait '),
#  ('tom left ', 'tom est parti '),
#  ('tom left ', 'tom partit '),
#  ('tom lied ', 'tom a menti '),
#  ('tom lies ', 'tom ment '),
#  ('tom lost ', 'tom a perdu '),
#  ('tom paid ', 'tom a pay '),
#  ('tom paid ', 'tom payait '),
#  ('tom went ', 'tom est parti '),
#  ('tom s up ', 'tom est debout '),
#  ('too late ', 'trop tard '),
#  ('touch it ', 'touchez le '),
#  ('touch it ', 'touchez la '),
#  ('touch it ', 'touche le '),
#  ('touch it ', 'touche la '),
#  ('trust me ', 'fais moi confiance '),
#  ('trust me ', 'faites moi confiance '),
#  ('trust me ', 'fais moi confiance '),
#  ('trust me ', 'ayez confiance en moi '),
#  ('trust me ', 'aie confiance en moi '),
#  ('try some ', 'essaies en '),
#  ('try some ', 'essayez en '),
#  ('try some ', 'essaie '),
#  ('try this ', 'essaie ceci '),
#  ('try this ', 'essayez ceci '),
#  ('try this ', 'essaye ceci '),
#  ('use this ', 'utilise ceci '),
#  ('use this ', 'utilisez ceci '),
#  ('use this ', 'emploie ceci '),
#  ('use this ', 'employez ceci '),
#  ('warn tom ', 'avertis tom '),
#  ('warn tom ', 'pr viens tom '),
#  ('watch me ', 'regarde moi '),
#  ('watch me ', 'regardez moi '),
#  ('watch us ', 'regardez nous '),
#  ('watch us ', 'regarde nous '),
#  ('we agree ', 'nous sommes d accord '),
#  ('we ll go ', 'nous irons '),
#  ('we re ok ', 'nous allons bien '),
#  ('what for ', 'pour quoi faire '),
#  ('what for ', ' quoi bon '),
#  ('what fun ', 'qu est ce qu on s est marr s '),
#  ('what fun ', 'qu est ce qu on s est marr es '),
#  ('who am i ', 'qui suis je '),
#  ('who came ', 'qui est venu '),
#  ('who died ', 'qui est mort '),
#  ('who fell ', 'qui est tomb '),
#  ('who lost ', 'qui a perdu '),
#  ('who paid ', 'qui a pay '),
#  ('who quit ', 'qui d missionne '),
#  ('who s he ', 'qui est il '),
#  ('write me ', ' cris moi '),
#  ('write me ', ' crivez moi '),
#  ('you lost ', 'tu as perdu '),
#  ('you lost ', 'vous avez perdu '),
#  ('you lost ', 't as perdu '),
#  ('after you ', 'je vous en prie '),
#  ('after you ', 'apr s vous '),
#  ('after you ', ' vous l honneur '),
#  ('after you ', ' toi l honneur '),
#  ('aim fire ', 'en joue feu '),
#  ('am i cute ', 'suis je mignon '),
#  ('am i late ', 'suis je en retard '),
#  ('answer me ', 'r pondez moi '),
#  ('be honest ', 'sois honn te '),
#  ('be honest ', 'soyez honn tes '),
#  ('be honest ', 'soyez honn te '),
#  ('be seated ', 'assieds toi '),
#  ('be seated ', 'asseyez vous '),
#  ('be seated ', 'asseyez vous '),
#  ('be strong ', 'sois puissante '),
#  ('birds fly ', 'les oiseaux volent '),
#  ('bless you ', ' tes souhaits '),
#  ('call home ', 'appelle la maison '),
#  ('calm down ', 'calmez vous '),
#  ('calm down ', 'du calme '),
#  ('calm down ', 'tranquille '),
#  ('calm down ', 'calme toi '),
#  ('calm down ', 'du calme '),
#  ('calm down ', 'tranquille '),
#  ('can we go ', 'pouvons nous partir '),
#  ('can we go ', 'pouvons nous nous en aller '),
#  ('can we go ', 'pouvons nous y aller '),
#  ('catch tom ', 'attrape tom '),
#  ('catch tom ', 'attrapez tom '),
#  ('catch him ', 'attrape le '),
#  ('catch him ', 'rattrape le '),
#  ('catch him ', 'saisissez le '),
#  ('chill out ', 'calme toi '),
#  ('chill out ', 'tranquille '),
#  ('choose me ', 'choisis moi '),
#  ('come back ', 'reviens '),
#  ('come back ', 'revenez '),
#  ('come here ', 'viens ici '),
#  ('come here ', 'venez l '),
#  ('come over ', 'venez ici '),
#  ('come over ', 'viens chez nous '),
#  ('come over ', 'venez chez nous '),
#  ('come over ', 'viens chez moi '),
#  ('come over ', 'venez chez moi '),
#  ('come soon ', 'viens bient t '),
#  ('come soon ', 'venez bient t '),
#  ('cool down ', 'calmez vous '),
#  ('did i win ', 'ai je gagn '),
#  ('did i win ', 'l ai je emport '),
#  ('did i win ', 'est ce moi qui ai gagn '),
#  ('do it now ', 'faites le maintenant '),
#  ('dogs bark ', 'des chiens aboient '),
#  ('dogs bark ', 'les chiens aboient '),
#  ('don t ask ', 'ne demande pas '),
#  ('don t cry ', 'ne pleure pas '),
#  ('don t die ', 'ne meurs pas '),
#  ('don t die ', 'ne mourez pas '),
#  ('don t lie ', 'ne mens pas '),
#  ('don t lie ', 'ne mens pas '),
#  ('don t run ', 'ne courez pas '),
#  ('don t run ', 'ne cours pas '),
#  ('excuse me ', 'excuse moi '),
#  ('excuse me ', 'excusez moi '),
#  ('excuse me ', 'pardon '),
#  ('excuse me ', 'je vous demande pardon '),
#  ('excuse me ', 'pla t il '),
#  ('excuse me ', 'plait il '),
#  ('excuse me ', 'pardon '),
#  ('fantastic ', 'fantastique '),
#  ('fantastic ', 'fantastique '),
#  ('fantastic ', 'sensass '),
#  ('feel this ', 'sens a '),
#  ('feel this ', 'sentez a '),
#  ('feel this ', 'touche a '),
#  ('feel this ', 'touchez a '),
#  ('film this ', 'filmez ceci '),
#  ('film this ', 'filme ceci '),
#  ('follow me ', 'suis moi '),
#  ('follow us ', 'suis nous '),
#  ('follow us ', 'suivez nous '),
#  ('forget it ', 'oublie '),
#  ('forget it ', 'oublie le '),
#  ('forget it ', 'oubliez '),
#  ('forget it ', 'oubliez le '),
#  ('forget it ', 'laissez tomber '),
#  ('forget it ', 'oubliez a '),
#  ('forget it ', 'laisse tomber '),
#  ('forget it ', 'oublie '),
#  ('forget it ', 'oublie le '),
#  ('forget it ', 'laissez tomber '),
#  ...]

# %%
#import library
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
#split data into training and testing sets
train_pairs, test_pairs = train_test_split(pairs, test_size=0.1, random_state=42)

# %%
#Tokenize french sentences
french_texts = [pair[0] for pair in train_pairs]
french_tokenizer = Tokenizer()
french_tokenizer.fit_on_texts(french_texts)
french_sentences  = french_tokenizer.texts_to_sequences(french_texts)
french_maxlen = max(len(sentence) for sentence in french_sentences)
french_sentences = pad_sequences(french_sentences, maxlen=french_maxlen, padding="post")

# %%
#Tokenize english sentences
english_texts = [pair[1] for pair in train_pairs]
english_tokenizer = Tokenizer()
english_tokenizer.fit_on_texts(english_texts)
english_sentences  = english_tokenizer.texts_to_sequences(english_texts)
french_maxlen = max(len(sentence) for sentence in french_sentences)
french_sentences = pad_sequences(french_sentences, maxlen=french_maxlen, padding="post")

# %%
# convert english sentences to one_hot_encoding
englsih_vocab_size = len(english_tokenizer.word_index) + 1
english_maxlen = max(len(sentence) for sentence in english_sentences) # Correctly use english_maxlen for shape
english_one_hot = np.zeros((len(english_sentences), english_maxlen, englsih_vocab_size), dtype="float32") # Corrected the shape
for i in range(len(english_sentences)):
    for j in range(len(english_sentences[i])):
        word_id = english_sentences[i][j]
        if word_id != 0:
            english_one_hot[i, j, word_id] = 1.0 # Now this should be within bounds
# print(english_one_hot)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, RepeatVector, TimeDistributed

# %%
#set model parameters
embedding_dim = 300
latent_dim = 512

# %%
#define encoder
encoder_inputs = Input(shape=(french_maxlen,))
encoder_embedding = Embedding(input_dim=len(french_tokenizer.word_index) + 1, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=False)(encoder_embedding)
encoder_output = RepeatVector(english_maxlen)(encoder_lstm)

# %%
#define decoder
decoder_lstm = LSTM(latent_dim, return_sequences=True)(encoder_output)
decoder_dense = TimeDistributed(Dense(englsih_vocab_size, activation="softmax"))(decoder_lstm)

# %%
#compile model
model = Model(inputs=encoder_inputs, outputs=decoder_dense)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 5)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, 5, 300)              │         543,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 512)                 │       1,665,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ repeat_vector (RepeatVector)         │ (None, 13, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 13, 512)             │       2,099,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed (TimeDistributed)   │ (None, 13, 3130)            │       1,605,690 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,913,514 (22.56 MB)
#  Trainable params: 5,913,514 (22.56 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#train model
model.fit(french_sentences, english_one_hot, epochs=40, validation_split=0.2)
# Out:
# Epoch 1/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.0213 - loss: 1.7379 - val_accuracy: 0.0368 - val_loss: 1.4235
# Epoch 2/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0444 - loss: 1.3508 - val_accuracy: 0.0477 - val_loss: 1.3404
# Epoch 3/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.0594 - loss: 1.2227 - val_accuracy: 0.0643 - val_loss: 1.2755
# Epoch 4/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.0708 - loss: 1.1111 - val_accuracy: 0.0686 - val_loss: 1.2351
# Epoch 5/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.0805 - loss: 1.0384 - val_accuracy: 0.0749 - val_loss: 1.2060
# Epoch 6/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0851 - loss: 0.9679 - val_accuracy: 0.0813 - val_loss: 1.1745
# Epoch 7/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0920 - loss: 0.8970 - val_accuracy: 0.0857 - val_loss: 1.1549
# Epoch 8/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.0970 - loss: 0.8328 - val_accuracy: 0.0895 - val_loss: 1.1364
# Epoch 9/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1033 - loss: 0.7871 - val_accuracy: 0.0908 - val_loss: 1.1202
# Epoch 10/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.1106 - loss: 0.7288 - val_accuracy: 0.0935 - val_loss: 1.1093
# Epoch 11/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1167 - loss: 0.6851 - val_accuracy: 0.0936 - val_loss: 1.1022
# Epoch 12/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1208 - loss: 0.6336 - val_accuracy: 0.0962 - val_loss: 1.0916
# Epoch 13/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1302 - loss: 0.5953 - val_accuracy: 0.0982 - val_loss: 1.0815
# Epoch 14/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.1349 - loss: 0.5551 - val_accuracy: 0.1000 - val_loss: 1.0736
# Epoch 15/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.1395 - loss: 0.5114 - val_accuracy: 0.1011 - val_loss: 1.0753
# Epoch 16/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.1478 - loss: 0.4669 - val_accuracy: 0.1038 - val_loss: 1.0656
# Epoch 17/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.1558 - loss: 0.4367 - val_accuracy: 0.1050 - val_loss: 1.0655
# Epoch 18/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.1634 - loss: 0.3992 - val_accuracy: 0.1036 - val_loss: 1.0689
# Epoch 19/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.1691 - loss: 0.3685 - val_accuracy: 0.1039 - val_loss: 1.0677
# Epoch 20/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.1751 - loss: 0.3486 - val_accuracy: 0.1054 - val_loss: 1.0684
# Epoch 21/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1797 - loss: 0.3234 - val_accuracy: 0.1073 - val_loss: 1.0726
# Epoch 22/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.1849 - loss: 0.2926 - val_accuracy: 0.1063 - val_loss: 1.0759
# Epoch 23/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.1904 - loss: 0.2766 - val_accuracy: 0.1085 - val_loss: 1.0779
# Epoch 24/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.1919 - loss: 0.2549 - val_accuracy: 0.1096 - val_loss: 1.0834
# Epoch 25/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.1969 - loss: 0.2374 - val_accuracy: 0.1102 - val_loss: 1.0907
# Epoch 26/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.1982 - loss: 0.2194 - val_accuracy: 0.1096 - val_loss: 1.0945
# Epoch 27/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2042 - loss: 0.2128 - val_accuracy: 0.1117 - val_loss: 1.0976
# Epoch 28/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2023 - loss: 0.2046 - val_accuracy: 0.1104 - val_loss: 1.1072
# Epoch 29/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2070 - loss: 0.1924 - val_accuracy: 0.1119 - val_loss: 1.1088
# Epoch 30/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.2101 - loss: 0.1808 - val_accuracy: 0.1114 - val_loss: 1.1145
# Epoch 31/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2094 - loss: 0.1706 - val_accuracy: 0.1117 - val_loss: 1.1164
# Epoch 32/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2113 - loss: 0.1662 - val_accuracy: 0.1111 - val_loss: 1.1224
# Epoch 33/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2134 - loss: 0.1626 - val_accuracy: 0.1122 - val_loss: 1.1301
# Epoch 34/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2142 - loss: 0.1564 - val_accuracy: 0.1116 - val_loss: 1.1366
# Epoch 35/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.2164 - loss: 0.1564 - val_accuracy: 0.1112 - val_loss: 1.1408
# Epoch 36/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.2159 - loss: 0.1485 - val_accuracy: 0.1128 - val_loss: 1.1463
# Epoch 37/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2163 - loss: 0.1439 - val_accuracy: 0.1121 - val_loss: 1.1539
# Epoch 38/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.2152 - loss: 0.1415 - val_accuracy: 0.1105 - val_loss: 1.1545
# Epoch 39/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2158 - loss: 0.1447 - val_accuracy: 0.1118 - val_loss: 1.1616
# Epoch 40/40
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.2126 - loss: 0.1393 - val_accuracy: 0.1120 - val_loss: 1.1705

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
references = []
candidates = []

# %%
for i in range(100):  # First 100 test sentences
    test_sentence = test_pairs[i][0]
    true_translation = test_pairs[i][1].split()

    # Convert test sentence to sequence
    test_sequence = french_tokenizer.texts_to_sequences([test_sentence])
    test_padded = pad_sequences(test_sequence, maxlen=french_maxlen, padding='post')

    # Make prediction
    prediction = model.predict(test_padded)
    predicted_sequence = np.argmax(prediction, axis=-1)[0]

    # Convert numbers back to words
    output_words = []
    for word_id in predicted_sequence:
        if word_id > 0 and word_id in english_tokenizer.index_word:
            output_words.append(english_tokenizer.index_word[word_id])

    references.append([true_translation])
    candidates.append(output_words)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
# Compute BLEU Score
bleu_scores = [sentence_bleu(ref, cand) for ref, cand in zip(references, candidates)]
print("Average BLEU Score:", np.mean(bleu_scores))
# Out:
# Average BLEU Score: 0.008693344347761088
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import numpy as np
import re
from tensorflow.keras.preprocessing.sequence import pad_sequences

def translate_input(input_sentence):
    # Preprocess the input sentence
    input_sentence = input_sentence.lower().strip()
    input_sentence = re.sub(r"[^a-zA-Z ]+", " ", input_sentence)

    # Convert sentence to sequence using the French tokenizer
    input_sequence = french_tokenizer.texts_to_sequences([input_sentence])

    # Pad the sequence to match model input length
    input_padded = pad_sequences(input_sequence, maxlen=french_maxlen, padding='post')

    # Make prediction using the model
    prediction = model.predict(input_padded)

    # Convert predicted indices to words (Greedy decoding)
    predicted_sequence = np.argmax(prediction, axis=-1)[0]

    # Convert tokenized output to English words
    output_words = []
    for word_id in predicted_sequence:
        if word_id == 0:  # Ignore padding tokens
            continue
        if word_id in english_tokenizer.index_word:
            word = english_tokenizer.index_word[word_id]
            if word not in output_words:  # Avoid repetition of words
                output_words.append(word)
        else:
            output_words.append("[UNK]")  # Handle unknown words gracefully

    # Join words to form a complete English sentence
    translated_sentence = " ".join(output_words)

    return translated_sentence.capitalize()

# Get input from the user
input_sentence = input("Enter a French sentence to translate: ")

# Translate the input sentence
translated_sentence = translate_input(input_sentence)

# Print the translated sentence
print("Translated sentence:", translated_sentence)
# Out:
# Enter a French sentence to translate: passe devant
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Translated sentence: C est heure nial pas
